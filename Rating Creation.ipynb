# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import csv
import pandas as pd
from rating_create import *
from sensitivity import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ROCurve()
# Out:
# {'203500': (0.5468277945619335, 0.6041666666666666), '203501': (0.47878787878787876, 0.5656565656565656), '203503': (0.515625, 0.64), '203504': (0.4583333333333333, 0.6), '203506': (0.4411764705882353, 0.6106870229007634), '203507': (0.5048076923076923, 0.5865384615384616), '203508': (0.5342465753424658, 0.5625), '203138': (0.5, 0.6568627450980392), '203133': (0.5338983050847458, 0.7631578947368421), '203135': (0.5170068027210885, 0.5384615384615384), '203136': (0.391304347826087, 0.5), '1495': (0.5574572127139364, 0.7037037037037037), '101161': (0.5085324232081911, 0.5352112676056338), '202696': (0.529126213592233, 0.717391304347826), '202695': (0.5416666666666666, 0.6984126984126984), '202694': (0.5138888888888888, 0.6578947368421053), '202693': (0.5370370370370371, 0.6463414634146342), '202692': (0.4319526627218935, 0.6588235294117647), '202691': (0.6167400881057269, 0.6694915254237288), '202690': (0.5576923076923077, 0.7391304347826086), '202699': (0.4981949458483754, 0.719626168
# ...

# %%
# Out:
# None

# %%
myData = pd.read_csv('shot_logs.csv')
off_rtg_atts = myData[['player_id',"PTS_TYPE","SHOT_RESULT"]]

# %%
off_rtg_atts.sort(['player_id'])
# Out:
# /home/vagrant/miniconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#         player_id  PTS_TYPE SHOT_RESULT
# 125389        708         2      missed
# 125184        708         2      missed
# 125185        708         2      missed
# 125186        708         2        made
# 125187        708         2        made
# 125188        708         2      missed
# 125189        708         2      missed
# 125183        708         2        made
# 125190        708         2        made
# 125192        708         2        made
# 125193        708         2      missed
# 125194        708         2        made
# 125195        708         2      missed
# 125196        708         2      missed
# 125197        708         2      missed
# 125191        708         2      missed
# 125182        708         2      missed
# 125181        708         2      missed
# ...

# %%
new_df = off_rtg_atts.groupby(['player_id','PTS_TYPE','SHOT_RESULT'])['SHOT_RESULT'].agg(['count'])
new_df
# Out:
#                                 count
# player_id PTS_TYPE SHOT_RESULT
# 708       2        made           139
#                    missed         155
#           3        made             1
#                    missed           6
# 977       2        made           212
#                    missed         317
#           3        made            54
#                    missed         130
# 1495      2        made           310
#                    missed         314
#           3        made             1
#                    missed           2
# 1713      2        made            50
#                    missed          73
#           3        made            44
#                    missed         116
# 1717      2        made           303
#                    missed         305
#           3        made            74
#                    missed         134
# 1718      2        made           149
#                    missed         147
#           3        made            91
# ...

# %%
row = next(new_df.iterrows())[1]
print row
row =  next(new_df.iterrows())[1]
print row
# Out:
# count    139
# Name: (708, 2, made), dtype: int64
# count    139
# Name: (708, 2, made), dtype: int64

# %%
row.next()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-98e57c10f327> in <module>()
# ----> 1 row.next()
#
# /home/vagrant/miniconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'next'
