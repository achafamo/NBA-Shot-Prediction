# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from plotting import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
make_bar_graph('shot_vs_def_dist')
make_bar_graph("shot_vs_distance")
make_bar_graph("shot_vs_period")

# %%
plot_two_vs_three()
